# %%
# !python detect.py --weight best3.pt --img 224 --source data/images --conf 0.5
# !python detect.py --source data/images --conf 0.5
# Out:
# detect: weights=['best3.pt'], source=data/images, data=data\coco128.yaml, imgsz=[224, 224], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  4878541 Python-3.9.12 torch-2.1.2+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 C:\Users\ayu\yolov5\data\images\helm.jpg: 160x224 1 helmet, 138.3ms
# image 2/8 C:\Users\ayu\yolov5\data\images\helm2.jpg: 160x224 1 helmet, 113.6ms
# image 3/8 C:\Users\ayu\yolov5\data\images\helm3.jpg: 160x224 2 heads, 1 helmet, 105.5ms
# image 4/8 C:\Users\ayu\yolov5\data\images\helm4.jpg: 160x224 4 heads, 1 helmet, 138.6ms
# ...
